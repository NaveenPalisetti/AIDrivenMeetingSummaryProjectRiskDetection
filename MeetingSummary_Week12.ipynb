# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/drive/MyDrive/Dissertation/Project/requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 117.2 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=d2107521950979aba89f965320d317972fe92869288e77dbcfdbb2f4d7fee5f4
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
# !pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/Dissertation/Project')

# %%
import evaluate
rouge_metric = evaluate.load("rouge")
bleu_metric = evaluate.load("bleu")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
# !python scripts/finetune_bart_meeting_summary.py
# Out:
# 2026-01-24 17:47:31.928199: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769276851.948882   12274 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769276851.954890   12274 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769276851.969633   12274 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python scripts/generate_summary.py data/Meeting_017_Transcript.txt
# Out:
# 2026-01-25 07:03:51.126650: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769324631.146448   20907 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769324631.152767   20907 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769324631.167945   20907 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/drive/MyDrive/Dissertation/Project/scripts/finetune.py --model_type distilbart --model_name /content/drive/MyDrive/Dissertation/Project/models/local_distilbart --train_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_train.csv --val_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output /content/drive/MyDrive/Dissertation/Project/models
# Out:
# 2025-12-13 13:56:49.531517: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-13 13:56:49.556433: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-13 13:56:49.611389: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765634209.676576    7721 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765634209.702611    7721 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/drive/MyDrive/Dissertation/Project/scripts/inference.py --model_type distilbart --model_name /content/drive/MyDrive/Dissertation/Project/models/distilbart_finetuned_meeting_summary --input_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output_csv /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_distilbart.csv
# Out:
# 2025-12-13 14:03:51.783437: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-13 14:03:51.792713: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-13 14:03:51.809142: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765634631.832715    9447 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765634631.839688    9447 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
pip install rouge_score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=a0e3a2ec7e7694b02eaf0164e84ae036746c003c60e641016f173b001dc8d0cc
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# ...

# %%
# !python /content/drive/MyDrive/Dissertation/Project/scripts/evaluate_rouge.py --csv_path /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_distilbart.csv --ref_col summary --pred_col generated_summary --model_name distilbart
# Out:
# ROUGE scores: {'rouge1': 0.8139515648779198, 'rougeL': 0.8139515648779198}
# ROUGE scores for distilbart saved/updated in /content/drive/MyDrive/Dissertation/Project/data/predictions/rouge_scores.json

# %%
##bart

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/finetune_bart.py --model_type bart --model_name /content/drive/MyDrive/Dissertation/Project/models/local_bart_base --train_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_train.csv --val_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output /content/drive/MyDrive/Dissertation/Project/models
# Out:
# 2025-12-07 18:21:17.386343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765131677.413986   15665 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765131677.423399   15665 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765131677.444438   15665 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/inference_bart.py --model_type bart --model_name /content/drive/MyDrive/Dissertation/Project/models/bart_finetuned_meeting_summary --input_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output_csv /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_bart.csv
# Out:
# 2025-12-07 18:34:00.692705: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765132440.723348   18712 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765132440.731199   18712 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765132440.751023   18712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/evaluate_rouge.py --csv_path /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_bart.csv --ref_col summary --pred_col generated_summary  --model_name bart
# Out:
# ROUGE scores: {'rouge1': 0.8571428571428572, 'rougeL': 0.8571428571428572}
# ROUGE scores for bart saved/updated in /content/drive/MyDrive/Dissertation/Project/data/predictions/rouge_scores.json

# %%
###pegasus:

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/finetune_bart.py --model_type pegasus --model_name /content/drive/MyDrive/Dissertation/Project/models/local_pegasus --train_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_train.csv --val_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output /content/drive/MyDrive/Dissertation/Project/models
# Out:
# 2025-12-09 16:06:31.011418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765296391.031212    2423 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765296391.037359    2423 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765296391.052205    2423 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/inference_bart.py --model_type pegasus --model_name /content/drive/MyDrive/Dissertation/Project/models/pegasus_finetuned_meeting_summary --input_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output_csv /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_pegasus.csv
# Out:
# 2025-12-09 16:16:04.837827: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765296965.097318    4816 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765296965.235306    4816 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765296966.677265    4816 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
pip install rouge_score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=70c6875d616345c5c4ccdad49c202f33ad39289d4b40d3b7c4a7121b614dd952
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# ...

# %% [markdown]
# # New Section

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/evaluate_rouge.py --csv_path /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_pegasus.csv --ref_col summary --pred_col generated_summary  --model_name pegasus
# Out:
# ROUGE scores: {'rouge1': 0.8666666666666667, 'rougeL': 0.8666666666666667}
# ROUGE scores for pegasus saved/updated in /content/drive/MyDrive/Dissertation/Project/data/predictions/rouge_scores.json

# %%
###t5:

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/finetune_bart.py --model_type t5 --model_name /content/drive/MyDrive/Dissertation/Project/models/local_t5_small --train_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_train.csv --val_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output /content/drive/MyDrive/Dissertation/Project/models
# Out:
# 2025-12-09 16:34:07.997718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765298048.342182    9469 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765298048.435791    9469 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765298049.035856    9469 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/inference_bart.py --model_type t5 --model_name /content/drive/MyDrive/Dissertation/Project/models/t5_finetuned_meeting_summary --input_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output_csv /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_t5.csv
# Out:
# 2025-12-09 16:36:01.144562: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765298161.171390   10028 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765298161.180061   10028 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765298161.218179   10028 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/evaluate_rouge.py --csv_path /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_t5.csv --ref_col summary --pred_col generated_summary  --model_name t5
# Out:
# ROUGE scores: {'rouge1': 0.4411571027617712, 'rougeL': 0.25857442925529395}
# ROUGE scores for t5 saved/updated in /content/drive/MyDrive/Dissertation/Project/data/predictions/rouge_scores.json

# %%
###tinybart:

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/finetune_bart.py --model_type tinybart --model_name /content/drive/MyDrive/Dissertation/Project/models/local_tinybart --train_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_train.csv --val_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output /content/drive/MyDrive/Dissertation/Project/models
# Out:
# 2025-12-09 17:02:43.667420: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765299763.941881   16643 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765299764.007126   16643 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765299764.509380   16643 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/inference_bart.py --model_type tinybart --model_name /content/drive/MyDrive/Dissertation/Project/models/tinybart_finetuned_meeting_summary --input_csv /content/drive/MyDrive/Dissertation/Project/data/processed/meeting_val.csv --output_csv /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_tinybart.csv
# Out:
# 2025-12-07 18:38:38.157375: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765132718.203553   19944 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765132718.216901   19944 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765132718.250048   19944 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
	# !python /content/drive/MyDrive/Dissertation/Project/scripts/evaluate_rouge.py --csv_path /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_t5.csv --ref_col summary --pred_col generated_summary  --model_name tinybart
# Out:
# CSV file /content/drive/MyDrive/Dissertation/Project/data/predictions/meeting_summaries_t5.csv not found. Please generate it first.
